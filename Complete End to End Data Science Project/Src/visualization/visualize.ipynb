# %% [markdown]
# **COMPANY:** INX FUTURE INC | EMPLOYEE PERFORMANCE ANALYSIS
#
# **BUISNESS CASE:** THE AIM IS TO PREDICT PREDICT THE PERFORMANCE RATING OF EMPLOYEES BASED ON THE PROVIDED DATASET FEATURES

# %% [markdown]
# # STEP BY STEP VISUALIZATION SUMMARY:
# 1. Domain Analysis Of all features
# 2. Univariate Analysis with insights
# 3. Bivariate Analysis with insights
# 4. Multivariat Analysis with insights

# %% [markdown]
# # IMPORTING ALL NECESSAERY LIBRARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')  # setting up background
from scipy import stats

# TO avoid warnings
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # LOADING DATA FOR VISUALIZATION

# %%
path = "/Users/mac/Documents/datascienceonecampus/DatamitesTraining/IABAC PROJECT ASSIGNMENT/Employee Performance Analysis/Data/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls"
data = pd.read_excel(path)
pd.set_option('display.max_columns',None) # Used to display the all features

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %% [markdown]
# # FEATURES DOMAIN KNOWLEDGE

# %% [markdown]
# **First, grasp the concept of "feature" and assess how independent features affect the dependent feature.**

# %% [markdown]
# ##### 1.EmpNumber:
# An Employee ID, also known as an Employee Number or Employee Code, is a distinctive numerical identifier assigned to each individual employee within an organization.
# ##### 2.Age:
# The "Age" feature in this dataset typically refers to the chronological age of employee. It represents the number of years since an individual's birth. Age is considered a continuous numerical variable
# "Age" is typically treated as a continuous variable, allowing for various statistical analyses, visualizations, and modeling techniques. It can also be grouped into categories or age ranges, such as "children," "adolescents," "young adults," "middle-aged," and "seniors," depending on the specific research or analysis goals. Age-related data can provide insights into various aspects of human behavior, experiences, and life stages.
#
# ##### 3.Gender:
# The "Gender" feature in this dataset represents the categorization of employees, typically based on their biological sex or self-identified gender identity. It is a categorical variable that serves to distinguish between male, female, and sometimes non-binary or other gender identities.
# Additionally, aggregating or analyzing gender data may involve grouping by categories (e.g., male, female, non-binary), and it's crucial to respect individuals' self-identified gender identities.
#
# ##### 4.EducationBackground:
# The "Education Background" feature typically describes the educational qualifications, levels, or fields of study completed by individuals employee. It is a categorical variable that provides information about the educational history of the data subjects.
# The "Education Background" feature may include various categories or levels, such as "High School Diploma," "Bachelor's Degree," "Master's Degree," "Doctorate," "Vocational Training," "Technical School," and more. In some cases, it may also include details about the field of study, major, or specialization.
# in data analysis is essential for exploring relationships between education and other variables, such as employment, income, health, and social outcomes. It can also be useful for identifying educational barriers and opportunities for improvement in educational systems.
#
# ##### 5.MaritalStatus:
# The "Marital Status" feature in a dataset provides information about the marital status of individuals, typically employees within an organization. It is a categorical nominal variable that describes an individual's current marital status.
# "Marital Status" data is typically recorded using categorical values, such as "Single," "Married," "Divorced," "Widowed," "Separated," or other relevant categories.
# this feature can be used to gain insights into the composition of the workforce and to assess whether certain policies or benefits align with the needs and preferences of employees based on their marital status. It is an important element in creating a supportive and inclusive work environment that considers the diverse needs of employees.
#
#
# ##### 6.EmpDepartment:
# The "Employee Department" feature in a dataset represents the specific department or functional unit within an organization to which an employee belongs or is assigned. It is a categorical variable that categorizes employees based on their roles or responsibilities within the company.
# The categories within "Employee Department" can vary widely, depending on the organization's structure and industry. For instance, a technology company might have departments like Engineering, Product Development, and IT, while a healthcare organization could have departments such as Nursing, Administration, and Patient Services.
# the "Employee Department" feature can be used to explore relationships with other variables like performance, salary, turnover rates, and more. It plays a vital role in organizational planning, decision-making, and understanding the dynamics of an organization's workforce.
#
# ##### 7.EmpJobRole:
# The "Employee Job Role" feature provides information about the specific job positions or roles held by individual employees within an organization. It is a categorical variable that categorizes employees based on their job functions and responsibilities.
# This can be diverse and specific to the organization's industry and structure. For example, in a tech company, job roles may include Software Developer, Data Analyst, Project Manager, and Network Engineer. In a healthcare organization, they may include Nurse, Physician, Administrative Assistant, and Lab Technician.
#  It plays a fundamental role in understanding the composition of the workforce and in managing and optimizing an organization's human resources.
#
# ##### 8.BusinessTravelFrequency:
# The "Employee Business Travel Frequency" feature in a dataset provides information about how frequently employees in an organization undertake business-related travel. It is a categorical variable that categorizes employees based on their travel patterns for work-related purposes.
# "Employee Business Travel Frequency" can vary depending on the organization's specific needs and travel policies. Common categories might include "Frequent Traveler," "Occasional Traveler," and "Rarely Travel" or similar distinctions
# feature can be used to examine relationships with other variables, such as performance, expenses, and job roles. It plays a crucial role in managing travel-related resources and policies and ensuring that business travel aligns with organizational goals and employee needs.
#
# ##### 9.DistanceFromHome:
# The "Employee Distance From Home" this provides information about the distance between an employee's place of residence and their workplace. It is a numerical variable that quantifies the distance in various units (e.g., miles, kilometers) and is used to measure the commuting distance for employees.
# feature is typically represented in numerical values, which can be used for quantitative analysis. The units of measurement for distance are often consistent with the country's standard (e.g., miles in the United States, kilometers in many other countries).
# this feature can be correlated with other variables like job roles, performance, job satisfaction, and more to understand its impact on employee behavior and outcomes. It plays a significant role in considering employee well-being, transportation planning, and workplace resource allocation.
#
# ##### 10.EmpEducationLevel:
# This feature in the dataset provides information about the educational qualifications and attainment levels of individual employees within an organization. It is a categorical variable that categorizes employees based on their highest completed level of education.
# The categories within "Employee Education Level" can vary but often include options such as "High School Diploma," "Bachelor's Degree," "Master's Degree," "Doctorate," "Vocational Training," "Some College," and "No Degree" or similar distinctions.
# the "Employee Education Level" feature can be used to explore relationships with other variables, such as job roles, performance, and salary. It is instrumental in understanding the educational qualifications of the workforce, planning for training and development, and making informed human resource decisions based on education backgrounds.
#
# ##### 11.EmpEnvironmentSatisfaction:
# The "Employee Environment Satisfaction" feature in a dataset provides information about employees' perceptions of their work environment and their satisfaction levels with various aspects of that environment. It is typically a numerical or categorical variable that quantifies or categorizes employees' satisfaction or dissatisfaction with their workplace.
# "Employee Environment Satisfaction" data can be collected through surveys, feedback mechanisms, and direct assessments. It may include subcategories or specific aspects of the work environment, such as relationships with colleagues, management, physical workspace, workload, and job security.
# this feature can be correlated with other variables like performance, turnover rates, and job satisfaction to understand its impact on the workforce and organizational performance. It plays a pivotal role in creating a positive and supportive work environment that fosters employee well-being and productivity.
#
# ##### 12.EmpHourlyRate:
# The "Employee Hourly Rate" feature in a dataset represents the hourly wage or rate of pay for individual employees within an organization. It is typically a numerical variable that quantifies the compensation employees receive on an hourly basis.
# The "Employee Hourly Rate" data can vary based on factors such as job role, seniority, location, and industry standards. It is crucial for ensuring fair compensation, complying with labor laws, and managing labor costs effectively.
# this feature can be used to examine relationships with other variables, such as job roles, performance, and overall compensation.
#
# ##### 13.EmpJobInvolvement:
# The "Employee Job Involvement" feature in a dataset provides information about the extent to which employees are emotionally and cognitively engaged in their work. It is a variable that measures or categorizes the level of an employee's job involvement.
# "Employee Job Involvement" can be measured through surveys, self-assessments, or through direct observation and feedback mechanisms. It may include categories or levels such as "Highly Involved," "Moderately Involved," "Low Involvement," or a numerical rating scale.
# this feature can be correlated with other variables like performance, job satisfaction, and retention rates to understand its impact on the workforce and organizational performance. It plays a crucial role in creating a positive and engaged work environment that fosters employee well-being and productivity.
#
# ##### 14.EmpJobLevel:
# The "Employee Job Level" feature in a dataset provides information about the hierarchical or job classification level of individual employees within an organization. It is a categorical or numerical variable that categorizes employees based on their job titles, roles, or seniority within the company's hierarchy.
# The categories within "Employee Job Level" can vary depending on the organization's structure and industry standards. Common categories might include "Entry-Level," "Mid-Level," "Senior-Level," and "Executive" or similar distinctions.
# the "Employee Job Level" feature can be used to explore relationships with other variables, such as performance, compensation, and succession planning. It is instrumental in understanding the composition of the workforce and making informed decisions related to organizational structure, staffing, and career development.
#
# ##### 15.EmpJobSatisfaction:
# The "Employee Job Satisfaction" feature in a dataset provides information about the level of satisfaction that individual employees experience in their current job roles within an organization. It is typically a numerical or categorical variable that quantifies or categorizes employee satisfaction.
# "Employee Job Satisfaction" can be measured through surveys, questionnaires, or other feedback mechanisms. It may include categories such as "Highly Satisfied," "Moderately Satisfied," "Low Satisfaction," or a numerical rating scale.
# this feature can be correlated with other variables like performance, retention rates, and turnover to understand its impact on the workforce and organizational performance. It plays a crucial role in creating a positive and supportive work environment that fosters employee well-being and productivity.
#
# ##### 16.NumCompaniesWorked:
# The "Employee Non-Companies Worked" feature in a dataset provides information about the number of non-company organizations or employers that an employee has worked for before joining the current organization. It is typically a numerical variable that quantifies the extent of an employee's work experience outside of the current company.
# "Employee Non-Companies Worked" data is often measured in terms of the number of organizations or employers an employee has worked for before joining the current company. It reflects the employee's career history and work adaptability.
# this feature can be correlated with other variables like job performance, career progression, and job satisfaction to understand its impact on the workforce and organizational performance. It plays a significant role in talent management, hiring decisions, and career development.
#
# ##### 17.OverTime:
# The "Employee Overtime" feature in a dataset provides information about the amount of additional hours an employee works beyond their regular or standard working hours. It is typically a numerical variable that quantifies the extent of overtime hours worked by employees.
# "Employee Overtime" data is typically recorded in terms of the number of hours worked beyond regular working hours. It may also include information about the frequency of overtime, such as daily, weekly, or occasional overtime.
# this feature can be correlated with other variables like job performance, employee satisfaction, and labor costs to understand its impact on the workforce and organizational performance. It plays a significant role in resource management, compensation, and ensuring the well-being of employees.
#
# ##### 18.EmpLastSalaryHikePercent:
# The "Employee Last Salary Hike Percent" feature in a dataset provides information about the percentage increase in an employee's salary during their most recent salary hike or adjustment. It is typically a numerical variable that quantifies the extent of the salary increase as a percentage.
# it is measured as a percentage, representing the increase in salary during the most recent adjustment.
# this feature can be correlated with other variables like job performance, job satisfaction, and employee retention to understand its impact on the workforce and organizational performance. It plays a pivotal role in compensation management, budgeting, and employee motivation and satisfaction.
#
# ##### 19.EmpRelationshipSatisfaction:
# The "Employee Relationship Satisfaction" feature in a dataset provides information about an employee's satisfaction with their relationships in the workplace, including interactions with colleagues, supervisors, and team members. It is typically a numerical or categorical variable that quantifies or categorizes an employee's level of satisfaction with workplace relationships.
# this feature can be correlated with other variables like job performance, retention rates, and engagement levels to understand its impact on the workforce and organizational performance. It plays a crucial role in creating a positive and supportive work environment that fosters employee well-being and productivity.
#
# ##### 20.TotalWorkExperienceInYears:
# The "Employee Total Work Experience In Years" feature in a dataset provides information about the total number of years an employee has spent working in their profession or field, including their current job and any previous employment. It is typically a numerical variable that quantifies an employee's cumulative work experience.
# "Employee Total Work Experience In Years" data is typically recorded as a numerical value, representing the cumulative number of years an employee has worked in their profession.
# this feature can be correlated with other variables like job performance, job fit, and career progression to understand its impact on the workforce and organizational performance. It plays a pivotal role in talent management, resource allocation, and succession planning.
#
# ##### 21.TrainingTimesLastYear:
# The "Employee Training Times Last Year" feature in a dataset provides information about the number of training sessions or courses that an employee participated in during the previous year. It is typically a numerical variable that quantifies the extent of an employee's training and development activities.
# "Employee Training Times Last Year" data is typically recorded as a numerical value representing the count of training sessions or courses completed by an employee in the previous year.
# this feature can be correlated with other variables like job performance, employee engagement, and career progression to understand its impact on the workforce and organizational performance. It plays a critical role in employee development, performance enhancement, and talent management.
#
#
# ##### 22.EmpWorkLifeBalance:
# The "Employee Work-Life Balance" feature in a dataset provides information about an employee's perception of the balance between their work responsibilities and personal life. It typically represents the level of satisfaction or dissatisfaction an employee feels regarding the harmony between work and personal life.
# "Employee Work-Life Balance" data is typically collected through surveys, questionnaires, or feedback mechanisms. It may include categories such as "Highly Satisfied," "Moderately Satisfied," "Low Satisfaction," or a numerical rating scale.
# this feature can be correlated with other variables like job performance, job satisfaction, and retention rates to understand its impact on the workforce and organizational performance. It plays a crucial role in creating a positive and supportive work environment that fosters employee well-being and productivity.
#
# ##### 23.ExperienceYearsAtThisCompany:
# The "Employee Work-Life Balance" feature in a dataset provides information about an employee's perception of the balance between their work responsibilities and personal life. It typically represents the level of satisfaction or dissatisfaction an employee feels regarding the harmony between work and personal life.
# "Employee Work-Life Balance" data is typically collected through surveys, questionnaires, or feedback mechanisms. It may include categories such as "Highly Satisfied," "Moderately Satisfied," "Low Satisfaction," or a numerical rating scale.
# this feature can be correlated with other variables like job performance, job satisfaction, and retention rates to understand its impact on the workforce and organizational performance. It plays a crucial role in creating a positive and supportive work environment that fosters employee well-being and productivity.
#
# ##### 24.ExperienceYearsInCurrentRole:
# The "Employee Experience Years In Current Role" feature in a dataset provides information about the number of years an employee has spent in their current job role or position within an organization. It is typically a numerical variable that quantifies the duration an employee has been working in their current role.
# "Employee Experience Years In Current Role" is typically recorded as a numerical value, representing the number of years an employee has spent in their current job role.
# this feature can be correlated with other variables like job performance, job fit, and career progression to understand its impact on the workforce and organizational performance. It plays a pivotal role in talent management, resource allocation, and succession planning.
#
# ##### 25.YearsSinceLastPromotion:
# Total no of year since last promotion of employee.
# The "Employee Years Since Last Promotion" feature in a dataset provides information about the number of years that have passed since an employee's most recent promotion within an organization. It is typically a numerical variable that quantifies the duration since an employee's last promotion.
# "Employee Years Since Last Promotion" data is typically recorded as a numerical value, representing the number of years that have passed since an employee's last promotion.
# this feature can be correlated with other variables like job performance, career progression, and retention rates to understand its impact on the workforce and organizational performance. It plays a pivotal role in career development, employee motivation, and succession planning.
#
# ##### 26.YearsWithCurrManager:
# The "Employee Years With Current Manager" feature in a dataset provides information about the number of years that an employee has been working under their current manager or supervisor within an organization. It is typically a numerical variable that quantifies the duration of the working relationship between an employee and their current manager.
# "Employee Years With Current Manager" data is typically recorded as a numerical value, representing the number of years an employee has been working under their current manager.
# this feature can be correlated with other variables like job performance, employee satisfaction, and retention rates to understand its impact on the workforce and organizational performance. It plays a pivotal role in assessing managerial effectiveness, employee satisfaction, and talent management.
#
# ##### 27.Attrition:
# The "Employee Attrition" feature in a dataset provides information about whether an employee has left or remained in their job or organization. It is typically a binary or categorical variable that indicates whether an employee has experienced attrition (left) or not (remained).
# "Employee Attrition" data is typically recorded as "Yes" or "No," "1" or "0," or other binary values, with "Yes" or "1" indicating attrition and "No" or "0" indicating no attrition.
# this feature is often used to examine attrition rates over time, identify trends, and conduct statistical analyses to uncover the underlying causes of attrition. It plays a pivotal role in human resource management, talent retention, and organizational success.
#
# ##### 28.PerformanceRating:
# The "Performance Rating" feature in a dataset provides information about the performance assessment or rating assigned to employees within an organization. It is typically a categorical or ordinal variable that quantifies an employee's performance based on predetermined criteria or metrics.
# "Performance Rating" data is typically recorded using categories or an ordinal scale, such as "Low," "Medium," "High," or numerical values like 1 to 5, with higher values indicating better performance.
# , this feature is often used for performance appraisals, identifying high and low performers, and conducting statistical analyses to understand the factors influencing performance. It plays a pivotal role in talent management, compensation, and career development within an organization.

# %% [markdown]
# # UNIVARIATE ANALYSIS
#
# Univariate analysis is a statistical method used in data analysis to examine and understand the characteristics and distribution of a single variable or feature in isolation. It focuses on one variable at a time and aims to provide insights into its distribution, central tendencies, variability, and other descriptive statistics.

# %% [markdown]
# continuous features
#
#     histogram: A histogram is a bar graph-like representation of data that buckets a range of classes into columns along the horizontal x-axis. The vertical y-axis represents the number count or percentage of occurrences in the data for each column.
#     lineplots:A Line plot can be defined as a graph that displays data as points or check marks above a number line, showing the frequency of each value.
#
# Discrete and Categorical
#
#     Countplot: countplot is used to Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# **1.Age: NUMERICAL CONTINOUS**

# %%
plt.figure(figsize=(10,7))
sns.histplot(x='Age',data=data)
plt.xlabel('Age',fontsize=20)
plt.show()

# %% [markdown]
# **Observation:**
#
# In the organization, the age range of employees spans from 18 to 60 years, with the majority falling within the age bracket of 25 to 40 years.

# %% [markdown]
# **2.Employee Hourly Rate: NUMERICAL CONTINOUS**

# %%
plt.figure(figsize=(10,7))
sns.histplot(x='EmpHourlyRate',data=data)
plt.xlabel('EmpHourlyRate',fontsize=20)
plt.show()

# %% [markdown]
# **Observation:**
#
# Within the company, the range of employee hourly rates varies from 30 to 100, but it's noteworthy that the most common hourly rate among employees is 45.

# %% [markdown]
# **3.Total Work Experience In Year**

# %%
plt.figure(figsize=(10,7))
sns.histplot(x='TotalWorkExperienceInYears',data=data)
plt.xlabel('TotalWorkExperienceInYears',fontsize=20)
plt.show()

# %% [markdown]
# **Observation:**
#
#     Work experiance range between 0 to 40,Most of the employee experiance ranges between 5 to 10.

# %% [markdown]
# **4.Experience Years At This Company**

# %%
plt.figure(figsize=(10,7))
sns.histplot(x='ExperienceYearsAtThisCompany',data=data)
plt.xlabel('ExperienceYearsAtThisCompany',fontsize=20)
plt.show()

# %% [markdown]
# **Observation:**
#
#     The Range of experiance in same comapny is 0 to 40,most of the employee join between 0 to 5.

# %% [markdown]
# # USE SUBPLOT TO PLOTS MULTIPLE FEATURE

# %%
count = data[['Gender', 'EducationBackground', 'MaritalStatus','BusinessTravelFrequency','DistanceFromHome',
              'EmpEducationLevel', 'EmpEnvironmentSatisfaction','EmpJobInvolvement', 'EmpJobLevel',
              'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime']] # making lsit of next 12 feature

plt.figure(figsize=(20,25)) # defining canvas size
plotno = 1 # counter

for column in count: # iteration of columns / acessing the columns from count 
    if plotno<=13:    # set the limit
        plt.subplot(4,3,plotno) # # plotting 12 graphs (4-rows,3-columns) ,plotnumber is for count
        sns.countplot(x=count[column]) # Plotting count plots because the feature data type is discerte and categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# # Observation:
# #### 5.Gender:
# * The graph suggests that a significant portion of the workforce in the company consists of male employees.
#
# #### 6.Education Background:
# * A significant portion of our workforce holds educational qualifications in Life Science and Medical fields, reflecting our commitment to excellence in healthcare-related industries. Additionally, we have over 100 employees with a background in marketing, highlighting our strong marketing and promotional capabilities across various sectors.
# * other eduacation background employee is less than 100.
#
# #### 7.MaritalStatus:
# * Most of the employee is married as well as less than 400 employee is single.
# * less than 300 employee mariatal status is divorced.
#
# #### 8.Business Travel Frequency:
# * Maximum no of employee travel rarely for company buisness purpose,less than 220 employee travel frequently
# * remaining less than 120 employee not travell for buisness purpose.
#
# #### 9.Distance From Home:
# * The range of distance between home to comapny is 1 to 29.
# * Maximum no of employee home to company distance is less than 10.
#
# #### 10.Educational Level:
# * Total range of educational level is 1 to 5,Maximum no of employee education level is 3 & 4.
# * 2 education level employee is less than 250 and remianing 1 & 5 education level employee is less than 150.
#
# #### 11.Employee Environment Satisfaction:
# * Most of the employee Statisfaction is 3 & 4
# * 1 & 2 enviroment satisfaction employee less than 250
#
# #### 12.Employee Job Involvement:
# * Most of the employee job involvement is 3 as well as 2 job involment employee is less than 300.
# * Remaining 1 and 4 job involvment employee is less than 100.
#
# #### 13.Employee Job Level:
# * The range of employee job kevel is 1 to 5,most of the employee job level is 1 & 2.
# * Minimum no of job level is 5, as well as 3 & 4 job level employee is less than 180.
#
# #### 14.Employee Job Satisfaction:
# * Most of the employee job satisfaction is 3 & 4 score as well as 1 & 2 score jon satisfaction employee is less than 250.
#
# #### 15.Number Companies Worked:
# * Maximum no of employee work with only one company.
# * less no of employee work in more than 5 companies.
#
# #### 16.Overtime:
# * Most no of employee on doing over time and less than 350 employee doing overtime in company.

# %%
count2 = data[['EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction','TrainingTimesLastYear','EmpWorkLifeBalance',
               'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion','YearsWithCurrManager', 'Attrition', 
               'PerformanceRating']]  #Making nex feature list to plot the graph

plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in count2: # iteration of columns / acessing the columns from count 
    if plotno<=10:    # set the limit
        plt.subplot(3,3,plotno) # # plotting 9 graphs (3-rows,3-columns) ,plotnumber is for count
        sns.countplot(x=count2[column]) # Plotting count plots because the feature data type is discerte and categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# # Observation:
# #### 17.Employee Last Salary Hike Percent:
# * Most no of employee salary hike percentage between 11 to 14%.total range of salary hike is 11 to 25.
# * less than 80 employee last salary hike in between 15 to 19.
#
# #### 18.Employee Relationship Satisfaction:
# * The range of employee relationship satisfaction is 1 to 4,Most of the relation satisfaction is 3 & 4 as well as less than 250 employee with 1 & 2 relationship satisfaction.
#
# #### 19.Training Times LastYear:
# * The range of training time in last year between 0 to 6, Most of the employee doing 2 & 3 rd time training and remaining all times is less than 100.
#
# #### 20.Employee Work Life Balance:
# * Most most the work life balance is 3 than less than 300 employee work life balance is 2.
# * Minimum work life balance is 1 as well as less than 100 employee work life balance is 4.
#
# #### 21.Experiance In Current Role:
# * Maximum current role experiance of employee is 18.
# * Most of the employee have 2 years of expriance in current role then 7 year of experiance employee is less than 180
# * less than 200 employee have not current role experiance.
#
# #### 22.Years Since Last Promotion:
# * The range of year since last promotion is 0 to 15.
# * Most of the employee has not promoted in last year less than 300 employee has promoted atleast 1 year.
#
# #### 23.Years With Current Manager:
# * Most employee have 2 years with current manager and minimum 16 years with current manager.
# * The range in between 0 to 17 and less than 180 employee has 7 years with current manager.
#
# #### 24.Attrition:
# * Maximum no of employee has not leave the company and less than 200 employee has going to leave the company.
#
# #### 25. Target Feature == Performance Rating:
# * The range of performance rating is 2 to 4, most of the employee have 3 performance ranting and less performance rating is 4.
# * less than 200 employee has 2 performance rating.

# %% [markdown]
# # 26.Employee Department

# %%
plt.figure(figsize=(10,7))
sns.countplot('EmpDepartment',data=data)
plt.xlabel('EmpDepartment',fontsize=20)
plt.show()

# %% [markdown]
# **Observation:**
#
# * Most of the employee from sales department as well as Development and research & Development departmnet employee is less than 320
# * Human resources & finance department employee is almost equal.
# * Data science employee has minimum in company.

# %% [markdown]
# # 27.Employee Job Role

# %%
plt.figure(figsize=(20,10))
sns.countplot('EmpJobRole',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('EmpJobRole',fontsize=20)
plt.show()

# %% [markdown]
# **Observation:**
#
#
# * Sales executive employee job role is maximum as well as Developer job role employee count is 230.
# * Manage R& D and research scientist employee is less than 100 and remaining all job role employee is less than 65.

# %% [markdown]
# # BIAVARIATE ANALYSIS
# * In Bivariate analysis Checking the relation between two features

# %% [markdown]
# #### ANALYSIS ON CONTINUOUS FEATURE
# #### PLOT USED:
# * Histogram, line plot used for continuous features
# * Count used for categorical & Discrete data.

# %% [markdown]
# # 1.Relation Between age & Experience Years At This Company

# %%
sns.lineplot(x='Age',y='TotalWorkExperienceInYears',data=data)
plt.xlabel('Age',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the age in between 18 to 25 then the total year of experiance is less than 5year.
# * If the age is increases that time experiance also increases.

# %% [markdown]
# # 2.Relation Between experiance year at this company & total work experiance

# %%
sns.lineplot(x='ExperienceYearsAtThisCompany',y='TotalWorkExperienceInYears',data=data)
plt.xlabel('ExperienceYearsAtThisCompany',fontsize=15)
plt.show()

# %% [markdown]
# # **Observation:**
#
# * If he experiance year at this company that time total work experiance also increases.

# %% [markdown]
# # 3.Relation between Employee last salary hike and number of company worked

# %%
sns.lineplot(x='EmpLastSalaryHikePercent',y='NumCompaniesWorked',data=data)
plt.xlabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the employee has work 1 or 2 company that time employee last salary hike percent is increases.

# %% [markdown]
# ## 4.Relation between Years Since Last Promotion and Experience Years In CurrentRole

# %%
sns.lineplot(x='YearsSinceLastPromotion',y='ExperienceYearsInCurrentRole',data=data)
plt.xlabel('YearsSinceLastPromotion',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * In above plot clearly seen that year since last promotion is increases that time employee has more experiance with current role

# %% [markdown]
# ## 5.Relation between Employee Hourly Rate and Years With Current Manager

# %%
sns.lineplot(x='EmpHourlyRate',y='YearsWithCurrManager',data=data)
plt.xlabel('EmpHourlyRate',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * most of the employee hourly rate with their current manager is constant,but some of the employees has maximum hourly rate with less no of year with current manager.

# %% [markdown]
# ## 6.Relation between Distance From Home and Employee Last Salary Hike Percent

# %%
sns.lineplot(x='DistanceFromHome',y='EmpLastSalaryHikePercent',data=data)
plt.xlabel('DistanceFromHome',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the distance from home is more then the employee salary hike is slightly increases.
# * distance from home between 10 to 13 that time employee salary hike is decreases.

# %% [markdown]
# ### ANALYSIS ON CATEGORICAL AND DISCERETE FEATURE

# %% [markdown]
# #### CREATE A NEW DATAFRAME FOR CATEGORICAL FEATURES.

# %%
categorical = []  # Create empty list to store the feature
for column in data.columns:
    if data[column].dtype == object:
        categorical.append(column)
        print(f"{column} : {data[column].unique()}")
        print("====================================")
# Out:
# EmpNumber : ['E1001000' 'E1001006' 'E1001007' ... 'E100994' 'E100995' 'E100998']
# ...
# Gender : ['Male' 'Female']
# ...
# EducationBackground : ['Marketing' 'Life Sciences' 'Human Resources' 'Medical' 'Other'
#  'Technical Degree']
# ...
# MaritalStatus : ['Single' 'Married' 'Divorced']
# ...
# EmpDepartment : ['Sales' 'Human Resources' 'Development' 'Data Science'
#  'Research & Development' 'Finance']
# ...
# EmpJobRole : ['Sales Executive' 'Manager' 'Developer' 'Sales Representative'
#  'Human Resources' 'Senior Developer' 'Data Scientist'
#  'Senior Manager R&D' 'Laboratory Technician' 'Manufacturing Director'
#  'Research Scientist' 'Healthcare Representative' 'Research Director'
#  'Manager R&D' 'Finance Manager' 'Technical Architect' 'Business Analyst'
#  'Technical Lead' 'Delivery Manager']
# ...
# BusinessTravelFrequency : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ...
# OverTime : ['No' 'Yes']
# ...
# Attrition : ['No' 'Yes']
# ...

# %%
categorical  # All categorical features
# Out:
# ['EmpNumber',
#  'Gender',
#  'EducationBackground',
#  'MaritalStatus',
#  'EmpDepartment',
#  'EmpJobRole',
#  'BusinessTravelFrequency',
#  'OverTime',
#  'Attrition']

# %%
# Make a list of categorical feature and use sub plot to plot multiple feature
categorical_col = data[['Gender','EducationBackground','MaritalStatus','BusinessTravelFrequency','OverTime','Attrition']]
plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in categorical_col: # iteration of columns / acessing the columns from count 
    if plotno<=7:    # set the limit
        plt.subplot(3,2,plotno) # # plotting 6 graphs (3-rows,2-columns) ,plotnumber is for count
        sns.countplot(x=categorical_col[column],hue=data.PerformanceRating) # Plotting count plots because the feature is categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
        plt.ylabel('PerformanceRating')
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# ### Observations:
# #### 7. Relationship between Gender and performance rating
# * Maximum no of male rated with 3 performance rating as well as in female also most of the feamle rated with 3 performance rating.
# * four performance rating in both male & female is less
#
# #### 8.Relationship between EducationBackground and performance rating
# * Maximum life sciences and medical education background employee rated with 3 performance rating
# * life science and medical education background employee also rated with 2 & 4 performance rating most of the time
#
# #### 9.Relationship between MaritalStatus and performance rating
# * Most of the married employee rated with 3 performance rating as well as single and divorced marital status employee rated with 3 performance rating most of the time.
# * In married marital status 2 performance rating emplyee is more than single or divorced.
#
# #### 10.Relationship between Business Travel Frequency and performance rating
# * Maximum no of travel rarely employee has get 3 performance rating
# * Those employee travel frequentaly this employee also rated with 2, 3, and 4
#
# #### 11.Relationship between Overtime and performance rating
# * Maximum no of employee with no overtime has rated with 3 perfomance rating
# * Those employee doing overtime that time 2 & 4 performance rating is constant.
#
# #### 12.Relationship between Attrition and performance rating
# * Most of the employee rated with 3 performance rating in no means(They are not leave the company)
# * Those employee have 3 performace rating those also leave the company

# %% [markdown]
# ### 13.Relationship between employee department and performance rating

# %%
plt.figure(figsize=(20,10))
sns.countplot('EmpDepartment',hue=data.PerformanceRating,data=data)
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('PerformanceRating',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * Most of the Development, Sales, And Research and development employee department has 3 peformance rating
# * Data science department employee has low performance rating.
# * In sales & Research and development department also 2 performance rating employee avilable most of the time.

# %% [markdown]
# ### 14.Relationship between employee job role and performance rating

# %%
plt.figure(figsize=(20,10))
sns.countplot('EmpJobRole',hue=data.PerformanceRating,data=data)
plt.xticks(rotation='vertical')
plt.xlabel('EmpJobRole',fontsize=20)
plt.ylabel('PerformanceRating',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * Developers and sales executive job role employee performance rating is 3 most of the time.
# * In technical architecture and delivery manger job role employee not rated with 2 & 4 performance rating.
# * In sales excutive alsso less than 60 employee rated with 2 performance rating.
# * Remaining all job role employee has 3 performance rating most of the time.

# %% [markdown]
# #### CREATE NEW DATAFRMAE FOR NUMERICAL FEATURES:

# %%
numerical_col = []
for column in data.columns:
    if data[column].dtype == "int64":
        data[column].unique()   # for continuos features we use unique>=10
        numerical_col.append(column)

# %%
numerical_col  # All numerical features
# Out:
# ['Age',
#  'DistanceFromHome',
#  'EmpEducationLevel',
#  'EmpEnvironmentSatisfaction',
#  'EmpHourlyRate',
#  'EmpJobInvolvement',
#  'EmpJobLevel',
#  'EmpJobSatisfaction',
#  'NumCompaniesWorked',
#  'EmpLastSalaryHikePercent',
#  'EmpRelationshipSatisfaction',
#  'TotalWorkExperienceInYears',
#  'TrainingTimesLastYear',
#  'EmpWorkLifeBalance',
#  'ExperienceYearsAtThisCompany',
#  'ExperienceYearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'PerformanceRating']

# %%
numerical = data[['EmpEducationLevel','EmpEnvironmentSatisfaction','EmpJobInvolvement','EmpJobLevel','EmpJobSatisfaction',
                 'EmpWorkLifeBalance']]

plt.figure(figsize=(20,22)) # defining canvas size
plotno = 1 # counter

for column in numerical: # iteration of columns / acessing the columns from count 
    if plotno<=7:    # set the limit
        plt.subplot(3,2,plotno) # # plotting 6 graphs (3-rows,2-columns) ,plotnumber is for count
        sns.countplot(x=numerical[column],hue=data.PerformanceRating) # Plotting count plots because the feature is categorical
        plt.xlabel(column,fontsize=20)  # assigning name to x-axis and font size is 20
        plt.ylabel('PerformanceRating')
    plotno+=1 # counter increment
plt.tight_layout()
plt.show() # used to hide the storage loction

# %% [markdown]
# ### Observations:
# #### 15. Relationship between EmpEducationLevel and performance rating
# * Those employee education level is [3,4 & 2] this employee have 3 peformance rating mostly
# * If the performance rating is 2 & 4 then all eduaction level employee is less than 60.
#
# #### 16. Relationship between EmpEnvironmentSatisfaction and performance rating
# * Maximum no of employee enviorment statifaction is 3 and 4 with 3 performance rating.
# * If the employee enviorment satisfaction is 1 & 2 that time the maximum employee have 2 performace rating.
# * If the employee enviorment satisfaction is increases that time 4 performance rating also increases.
#
# #### 17. Relationship between EmpJobInvolvement and performance rating
# * Those employee job involvement is 2 & 3 this empluee have 3 performance rating mostly
# * 2 & 4 performance rating eployee is less in all job involvment.
#
#
# #### 18. Relationship between EmpJobLevel and performance rating
# * If the employee job level is 1,2 & 3 that time most of the employee have 3 performance rating
# * In all job levels 2 & 4 performance rating of all emplyee is less than 60.
#
# #### 19. Relationship between EmpJobSatisfaction and performance rating
# * Maximum 4 & 3 job satisfaction employee get 3 performance rating most of the time.
# * In all job satisfaction 2 & 4 performance rating is less than 55 employee
#
# #### 21. Relationship between EmpWorkLifeBalance and performance rating
# * If the employee work life balance is 3 that time maximum no of employee have 3 performance rating.
# * If the work life balance is 1 that time no one get 4 performance rating.

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %% [markdown]
# * Checking the relationship between two features with respect to target features

# %% [markdown]
# #### PLOT USED:
# **Line plot:** A Line plot can be defined as a graph that displays data as points or check marks above a number line, showing the frequency of each value.
# **Barplot:** It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.

# %% [markdown]
# **1.Check the relationship between Age & Total work experiance with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Age',y='TotalWorkExperienceInYears',hue=data.PerformanceRating,data=data)
plt.xlabel('Age',fontsize=20)
plt.ylabel('TotalWorkExperienceInYears',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the age & total experiance is increases that time most of the employee performance rating is 4.
# * Low age and minimum year experiance employee also 4 perfomace rating.
# * At the age of 50 and 30 years of experiance employee have 2 performance rating.

# %% [markdown]
# **2.Check the relationship between Gender & Number Companies Worked with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Gender',y='NumCompaniesWorked',hue=data.PerformanceRating,data=data)
plt.xlabel('Gender',fontsize=20)
plt.ylabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the gender is male and no of companies work is increses that time most of the performance rating is 2 & 4.
# * If female work in less no companies that time performance rating is 2.
# * 3 & 4 performance rating in female increase if the no of compaines worked is increses.

# %% [markdown]
# **3.Check the relationship between MaritalStatus & EmpLastSalaryHikePercent with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='MaritalStatus',y='EmpLastSalaryHikePercent',hue=data.PerformanceRating,data=data)
plt.xlabel('MaritalStatus',fontsize=20)
plt.ylabel('EmpLastSalaryHikePercent',fontsize=15)
plt.show()

# %% [markdown]
# **Observatopn:**
#
# * In all marital status with maximum salary hike percent in last year is increases that time performance rating is 4.
# * If salary hike percentage in last year is less than 15 that time performance rating is 2 & 3 in all marital status.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='BusinessTravelFrequency',y='EmpEnvironmentSatisfaction',hue=data.PerformanceRating,data=data)
plt.xlabel('BusinessTravelFrequency',fontsize=20)
plt.ylabel('EmpEnvironmentSatisfaction',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the employee enviorment satisfaction is high that time performance rating is 3 & 4 in all buisness travel frequency.
# * Low employee enviorment satisfaction has 2 performance rating in all buisness travel frequency.

# %% [markdown]
# **5.Check the relationship between Attrition & YearsWithCurrManager with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='YearsWithCurrManager',hue=data.PerformanceRating,data=data)
plt.xlabel('Attrition',fontsize=20)
plt.ylabel('YearsWithCurrManager',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# * If the employee current manager year is increses that time performance rating is 2 and 50-50% chances of employee to leave the company.
# * those employee perfomance rating is 4 and current manger year is increases that time most of the employee not leave the company.

# %% [markdown]
# **6.Check the relationship between EducationBackground & ExperienceYearsInCurrentRole with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EducationBackground',y='ExperienceYearsInCurrentRole',hue=data.PerformanceRating,data=data)
plt.xlabel('EducationBackground',fontsize=20)
plt.ylabel('ExperienceYearsInCurrentRole',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the current role experiance is increses of marketing education background employee has 4 performance rating most of the time
# * In all education background with current role experiance is more than 5 then the performance rating of employee is 2.
# * Life scineces, Medical, others , and technical degree education background employee has less than 4 year of experiance in current role that time performance rating is 3 & 4.

# %% [markdown]
# **7.Check the relationship between OverTime & DistanceFromHome with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='OverTime',y='DistanceFromHome',hue=data.PerformanceRating,data=data)
plt.xlabel('OverTime',fontsize=20)
plt.ylabel('DistanceFromHome',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the distance from home is increses that time performance rating is constant with employee doing overtime as well as not doing overtime.

# %% [markdown]
# **8.Check the relationship between EmpDepartment & TrainingTimesLastYear with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='EmpDepartment',y='TrainingTimesLastYear',hue=data.PerformanceRating,data=data)
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('TrainingTimesLastYear',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
#
# * If the employee from data science department and most training time in last year then the performance rating is 2 maximum time.
# * Other all employee department with less than 3 time training in last year then the peroformance rating is constant.

# %% [markdown]
# **10.Check the relationship between Attrition &  NumCompaniesWorked with respect to target feature**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Attrition',y='NumCompaniesWorked',hue=data.PerformanceRating,data=data)
plt.xlabel('Attrition',fontsize=20)
plt.ylabel('NumCompaniesWorked',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:**
# * If emplyee number of companies worked is increses that time most of the employee leave the company and their performance rating is 2
# * Those employee have work in less no of companies they are not leave the company and their performance rating is constant.

# %% [markdown]
# #### CONCLUSION
# * There are some features are positively correlated with performance rating( Target variable)
# [Emp Environment Satisfaction,Emp Last Salary Hike Percent,Emp Work Life Balance]
